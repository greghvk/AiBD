# %%
import pyreadstat

import numpy as np
import pandas as pd

# %%
original_df, meta = pyreadstat.read_sav("pew.sav")

# %%
df = original_df.copy()

# %%
for col, label in zip(meta.column_names, meta.column_labels):
    print(col + ":")
    print(label + '\n')
# Out:
# weight:
# Sample weight for all landline respondents -- RECOMMENDED FOR USE IN ALL ANALYSES
#
# psraid:
# Unique ID
#
# int_date:
# Interview date
#
# lang:
# Language of Interview
#
# type:
# Type of sample used
#
# cregion:
# Census region
#
# state:
# State from FIPS
#
# usr:
# Community type - alpha
#
# usr1:
# Community type - numeric
#
# form:
# Form split
#
# density3:
# Population density (quintiles)
#
# q1:
# Q.1 All in all, are you satisfied or dissatisfied with the way things are going in this country today?
#
# q1a:
# Q.1a Would you say that's very satisfied/dissatisfied or just somewhat satisfied/dissatisfied?
#
# q2:
# Q.2 All in all, are you satisfied or dissatisfied with the way things are going in your personal life?
#
# q2a:
# Q.2a Would you say that's very satisfied/dissatisfied or just somewhat satisfied/dissatisfied?
#
# q3a:
# ...

# %%
df = pd.DataFrame(df, index=df['psraid'])

# %%
df
# Out:
#             weight  psraid  int_date  lang  type  cregion  state  usr  usr1  \
# psraid
# 10000001.0     NaN     NaN       NaN   NaN   NaN      NaN    NaN  NaN   NaN
# 10000002.0     NaN     NaN       NaN   NaN   NaN      NaN    NaN  NaN   NaN
# 10000003.0     NaN     NaN       NaN   NaN   NaN      NaN    NaN  NaN   NaN
# 10000004.0     NaN     NaN       NaN   NaN   NaN      NaN    NaN  NaN   NaN
# 10000005.0     NaN     NaN       NaN   NaN   NaN      NaN    NaN  NaN   NaN
# ...            ...     ...       ...   ...   ...      ...    ...  ...   ...
# 90000869.0     NaN     NaN       NaN   NaN   NaN      NaN    NaN  NaN   NaN
# 90000871.0     NaN     NaN       NaN   NaN   NaN      NaN    NaN  NaN   NaN
# 90000873.0     NaN     NaN       NaN   NaN   NaN      NaN    NaN  NaN   NaN
# 90000876.0     NaN     NaN       NaN   NaN   NaN      NaN    NaN  NaN   NaN
# 90000877.0     NaN     NaN       NaN   NaN   NaN      NaN    NaN  NaN   NaN
#
# ...
